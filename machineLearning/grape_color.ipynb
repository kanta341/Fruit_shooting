# %%
# ============================================================
# Grape_new colorization model: border 128x128 -> RGB + alpha 400x400
#
# Input:
#   border 128x128 binary line image
#
# Target:
#   color image originally 400x400
#   used as 400x400 target
#
# Output:
#   RGBA 400x400
#
# Dataset zip:
#   /content/drive/MyDrive/borderModel2/grape_ver1/color.zip
#
# Expected structure inside zip:
#   color/
#     color_dataset/
#       grape_new/
#         1.png
#         2.png
#         ...
#     border_dataset/
#       grape_new/
#         1.png
#         2.png
#         ...
# ============================================================

from google.colab import drive
drive.mount('/content/drive')

import os
import json
import random
import shutil
import zipfile
from pathlib import Path

import numpy as np
from PIL import Image, ImageDraw, ImageFilter

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
from tqdm.auto import tqdm


# ============================================================
# Basic config
# ============================================================

PROJECT_ROOT = Path("/content/drive/MyDrive/borderModel2/grape_ver1")

DATASET_NAME = "grape_new"

COLOR_ZIP_PATH = PROJECT_ROOT / "color.zip"
LOCAL_COLOR_ROOT = Path("/content/grape_new_color_data_128to400")

EXP_DIR = PROJECT_ROOT / "experiments" / "exp_color_rgba_128to400_grape_new_v001"
CHECKPOINT_DIR = EXP_DIR / "checkpoints"
SAMPLE_DIR = EXP_DIR / "samples"
LOG_DIR = EXP_DIR / "logs"

for d in [EXP_DIR, CHECKPOINT_DIR, SAMPLE_DIR, LOG_DIR]:
    d.mkdir(parents=True, exist_ok=True)


CONFIG = {
    # Dataset
    "dataset_name": DATASET_NAME,

    # I/O size
    "input_border_size": 128,
    "output_color_size": 400,

    # Data split
    "train_ratio": 0.8,
    "val_ratio": 0.1,
    "test_ratio": 0.1,
    "random_seed": 42,

    # 新データセットなので、古いsplitを誤用しないため基本False推奨
    # 同じ実験ディレクトリで再実行する場合だけTrueでもよい
    "reuse_existing_split": True,

    # Training
    "batch_size": 8,
    "epochs": 80,
    "learning_rate": 1e-3,
    "weight_decay": 1e-4,
    "early_stopping_patience": 15,

    # Runtime
    "num_workers": 0,
    "use_amp": True,

    # Model
    "input_channels": 1,
    "output_channels": 4,   # RGB(3) + alpha(1)
    "base_channels": 24,

    # Alpha target generation from white background
    "white_bg_threshold": 245,

    # Loss weights
    "rgb_loss_weight": 5.0,
    "alpha_bce_weight": 1.0,
    "alpha_dice_weight": 1.0,
    "background_rgb_weight": 0.0,

    # Inference / metric threshold
    "alpha_threshold": 0.5,

    # Augmentation
    "use_train_augmentation": True,

    # shared scaling only. No rotation / no flip.
    "shared_scale_prob": 0.50,
    "shared_scale_min": 0.94,
    "shared_scale_max": 1.06,

    # border-only degradation
    "border_dropout_prob": 0.30,
    "border_dropout_holes_min": 1,
    "border_dropout_holes_max": 3,
    "border_dropout_radius_min": 1,
    "border_dropout_radius_max": 3,

    "border_width_jitter_prob": 0.20,
    "border_noise_stroke_prob": 0.10,

    # Zip handling
    # grape_new を新しくzipへ追加した直後なら True 推奨
    # /content 側に古い展開済みデータが残っている可能性を潰せる
    "force_reextract_color_zip": True,
}

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PIN_MEMORY = DEVICE.type == "cuda"

print("DEVICE:", DEVICE)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

random.seed(CONFIG["random_seed"])
np.random.seed(CONFIG["random_seed"])
torch.manual_seed(CONFIG["random_seed"])
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(CONFIG["random_seed"])

with open(EXP_DIR / "config.json", "w", encoding="utf-8") as f:
    json.dump(CONFIG, f, indent=2, ensure_ascii=False)


# ============================================================
# Extract color.zip
# ============================================================

if not COLOR_ZIP_PATH.exists():
    raise FileNotFoundError(f"color.zip not found: {COLOR_ZIP_PATH}")

if CONFIG["force_reextract_color_zip"] and LOCAL_COLOR_ROOT.exists():
    print("Removing existing extracted dir:", LOCAL_COLOR_ROOT)
    shutil.rmtree(LOCAL_COLOR_ROOT)

LOCAL_COLOR_ROOT.mkdir(parents=True, exist_ok=True)

already_extracted = len(list(LOCAL_COLOR_ROOT.rglob("*.png"))) > 0

if already_extracted and not CONFIG["force_reextract_color_zip"]:
    print("color.zip already extracted. Reusing:", LOCAL_COLOR_ROOT)
else:
    print("Extracting color.zip...")
    with zipfile.ZipFile(COLOR_ZIP_PATH, "r") as z:
        z.extractall(LOCAL_COLOR_ROOT)
    print("Extracted to:", LOCAL_COLOR_ROOT)

print("\nExtracted top-level:")
for p in LOCAL_COLOR_ROOT.iterdir():
    print(" ", p)


# ============================================================
# Find dataset directories
# ============================================================

def image_count(path: Path) -> int:
    count = 0
    for ext in ["*.png", "*.PNG", "*.jpg", "*.JPG", "*.jpeg", "*.JPEG", "*.webp", "*.WEBP"]:
        count += len(list(path.glob(ext)))
    return count


def find_dataset_dir(root: Path, target_parts: tuple[str, str]) -> Path:
    """
    Find a directory whose final path parts match target_parts.
    Example:
      target_parts=("border_dataset", "grape_new")
      target_parts=("color_dataset", "grape_new")
    """
    candidates = []

    for p in root.rglob(target_parts[-1]):
        if not p.is_dir():
            continue

        parts = p.parts
        if len(parts) >= len(target_parts):
            if tuple(parts[-len(target_parts):]) == target_parts:
                candidates.append(p)

    if len(candidates) == 0:
        print("\nDirectories under extracted root:")
        for p in root.rglob("*"):
            if p.is_dir():
                print(p)
        raise FileNotFoundError(f"Could not find directory ending with: {target_parts}")

    best = max(candidates, key=image_count)

    print(f"\nFound {target_parts}: {best}")
    print("Image count:", image_count(best))

    return best


BORDER_DIR = find_dataset_dir(LOCAL_COLOR_ROOT, ("border_dataset", DATASET_NAME))
COLOR_DIR = find_dataset_dir(LOCAL_COLOR_ROOT, ("color_dataset", DATASET_NAME))

print("\nFinal dataset dirs:")
print("BORDER_DIR:", BORDER_DIR)
print("COLOR_DIR:", COLOR_DIR)


# ============================================================
# Image pair collection
# ============================================================

def list_image_files(path: Path):
    exts = ["*.png", "*.PNG", "*.jpg", "*.JPG", "*.jpeg", "*.JPEG", "*.webp", "*.WEBP"]
    files = []
    for ext in exts:
        files.extend(path.glob(ext))
    return sorted(files)


def collect_pairs(border_dir: Path, color_dir: Path):
    border_list = list_image_files(border_dir)
    color_list = list_image_files(color_dir)

    print("\nBorder files found:", len(border_list))
    print("Color files found:", len(color_list))

    print("Border examples:", [p.name for p in border_list[:10]])
    print("Color examples:", [p.name for p in color_list[:10]])

    border_files = {p.stem: p for p in border_list}
    color_files = {p.stem: p for p in color_list}

    common_stems = sorted(
        set(border_files.keys()) & set(color_files.keys()),
        key=lambda x: int(x) if x.isdigit() else x
    )

    pairs = []
    for stem in common_stems:
        pairs.append({
            "name": f"{stem}.png",
            "stem": stem,
            "border_path": border_files[stem],
            "color_path": color_files[stem],
        })

    missing_in_color = sorted(set(border_files.keys()) - set(color_files.keys()))
    missing_in_border = sorted(set(color_files.keys()) - set(border_files.keys()))

    print("Matched pairs:", len(pairs))
    print("Missing in color:", len(missing_in_color))
    print("Missing in border:", len(missing_in_border))

    if missing_in_color:
        print("Missing in color examples:", missing_in_color[:10])
    if missing_in_border:
        print("Missing in border examples:", missing_in_border[:10])

    return pairs


all_pairs = collect_pairs(BORDER_DIR, COLOR_DIR)

if len(all_pairs) == 0:
    raise RuntimeError("No matched border/color pairs found.")


# ============================================================
# Utility functions
# ============================================================

def pil_rgb_to_tensor(img: Image.Image) -> torch.Tensor:
    arr = np.asarray(img).astype(np.float32) / 255.0
    arr = np.transpose(arr, (2, 0, 1))
    return torch.from_numpy(arr)


def pil_gray_mask_to_tensor(img: Image.Image) -> torch.Tensor:
    arr = np.asarray(img).astype(np.float32) / 255.0
    return torch.from_numpy(arr).unsqueeze(0)


def tensor_to_rgb_numpy(t: torch.Tensor) -> np.ndarray:
    x = t.detach().cpu().clamp(0, 1).numpy()
    return np.transpose(x, (1, 2, 0))


def tensor_to_gray_numpy(t: torch.Tensor) -> np.ndarray:
    return t.detach().cpu().clamp(0, 1).squeeze(0).numpy()


def make_checkerboard(h, w, tile=20):
    yy, xx = np.indices((h, w))
    board = ((yy // tile + xx // tile) % 2).astype(np.float32)
    board = 0.85 + board * 0.10
    return np.stack([board, board, board], axis=-1)


def alpha_composite_on_checker(rgb: np.ndarray, alpha: np.ndarray) -> np.ndarray:
    bg = make_checkerboard(rgb.shape[0], rgb.shape[1], tile=20)
    alpha3 = alpha[..., None]
    return rgb * alpha3 + bg * (1.0 - alpha3)


def center_scale_pil(
    img: Image.Image,
    scale: float,
    out_size: int,
    resample,
    fill
) -> Image.Image:
    w, h = img.size
    new_w = max(1, int(round(w * scale)))
    new_h = max(1, int(round(h * scale)))
    resized = img.resize((new_w, new_h), resample=resample)

    canvas = Image.new(img.mode, (out_size, out_size), color=fill)
    paste_x = (out_size - new_w) // 2
    paste_y = (out_size - new_h) // 2
    canvas.paste(resized, (paste_x, paste_y))
    return canvas


def load_border_image(path: Path, out_size: int) -> Image.Image:
    """
    Border image:
      original expected: 128x128 binary line image

    Internal PIL representation:
      line = 255
      background = 0
    """
    img = Image.open(path).convert("L")

    if img.size != (out_size, out_size):
        img = img.resize((out_size, out_size), Image.NEAREST)

    arr = np.asarray(img)
    mask = (arr < 128).astype(np.uint8) * 255
    return Image.fromarray(mask).convert("L")


def create_alpha_from_color_image(
    path: Path,
    out_size: int,
    white_threshold: int
) -> tuple[Image.Image, Image.Image]:
    """
    Color image:
      Original is usually 400x400 RGB with white background.
      This version uses 400x400 target.
      Alpha target is generated from non-white pixels.
    """
    rgb = Image.open(path).convert("RGB")

    if rgb.size != (out_size, out_size):
        rgb = rgb.resize((out_size, out_size), Image.BICUBIC)

    arr = np.asarray(rgb)

    alpha = np.logical_not(
        (arr[:, :, 0] >= white_threshold) &
        (arr[:, :, 1] >= white_threshold) &
        (arr[:, :, 2] >= white_threshold)
    ).astype(np.uint8) * 255

    alpha_img = Image.fromarray(alpha).convert("L")
    return rgb, alpha_img


def apply_shared_scaling(
    border_img: Image.Image,
    rgb_img: Image.Image,
    alpha_img: Image.Image,
    rng: np.random.Generator,
):
    """
    Same scale is applied to border 128 and target 400.
    Each image is scaled around its own center.
    """
    if rng.random() >= CONFIG["shared_scale_prob"]:
        return border_img, rgb_img, alpha_img

    scale = float(rng.uniform(CONFIG["shared_scale_min"], CONFIG["shared_scale_max"]))

    border_img = center_scale_pil(
        border_img,
        scale=scale,
        out_size=CONFIG["input_border_size"],
        resample=Image.NEAREST,
        fill=0
    )

    rgb_img = center_scale_pil(
        rgb_img,
        scale=scale,
        out_size=CONFIG["output_color_size"],
        resample=Image.BICUBIC,
        fill=(255, 255, 255)
    )

    alpha_img = center_scale_pil(
        alpha_img,
        scale=scale,
        out_size=CONFIG["output_color_size"],
        resample=Image.NEAREST,
        fill=0
    )

    return border_img, rgb_img, alpha_img


def degrade_border_only(border_img: Image.Image, rng: np.random.Generator) -> Image.Image:
    """
    Simulate imperfect output from the previous border-completion model:
      - small gaps
      - line width jitter
      - small false strokes
    """
    img = border_img.copy()

    if rng.random() < CONFIG["border_dropout_prob"]:
        draw = ImageDraw.Draw(img)
        arr = np.asarray(img)
        ys, xs = np.where(arr > 127)

        if len(xs) > 0:
            n_holes = int(rng.integers(
                CONFIG["border_dropout_holes_min"],
                CONFIG["border_dropout_holes_max"] + 1
            ))

            for _ in range(n_holes):
                idx = int(rng.integers(0, len(xs)))
                x = int(xs[idx])
                y = int(ys[idx])
                r = int(rng.integers(
                    CONFIG["border_dropout_radius_min"],
                    CONFIG["border_dropout_radius_max"] + 1
                ))
                draw.ellipse((x - r, y - r, x + r, y + r), fill=0)

    if rng.random() < CONFIG["border_width_jitter_prob"]:
        k = 3
        if rng.random() < 0.5:
            img = img.filter(ImageFilter.MaxFilter(k))
        else:
            img = img.filter(ImageFilter.MinFilter(k))

    if rng.random() < CONFIG["border_noise_stroke_prob"]:
        draw = ImageDraw.Draw(img)
        arr = np.asarray(img)
        ys, xs = np.where(arr > 127)

        if len(xs) > 0:
            idx = int(rng.integers(0, len(xs)))
            x0 = int(xs[idx])
            y0 = int(ys[idx])

            length = int(rng.integers(3, 10))
            angle = float(rng.uniform(0, 2 * np.pi))

            x1 = int(round(x0 + np.cos(angle) * length))
            y1 = int(round(y0 + np.sin(angle) * length))

            draw.line(
                (x0, y0, x1, y1),
                fill=255,
                width=1
            )

    arr = np.asarray(img)
    arr = (arr > 127).astype(np.uint8) * 255
    return Image.fromarray(arr).convert("L")


# ============================================================
# Split
# ============================================================

def build_or_load_split(pairs, exp_dir: Path):
    split_path = exp_dir / "split.json"

    if CONFIG["reuse_existing_split"] and split_path.exists():
        print("\nLoading existing split:", split_path)
        with open(split_path, "r", encoding="utf-8") as f:
            split_data = json.load(f)

        pair_dict = {x["stem"]: x for x in pairs}

        train_pairs = [pair_dict[stem] for stem in split_data["train"] if stem in pair_dict]
        val_pairs = [pair_dict[stem] for stem in split_data["val"] if stem in pair_dict]
        test_pairs = [pair_dict[stem] for stem in split_data["test"] if stem in pair_dict]

        print("Loaded split counts:")
        print("Train:", len(train_pairs))
        print("Val:", len(val_pairs))
        print("Test:", len(test_pairs))

        if len(train_pairs) == 0 or len(val_pairs) == 0 or len(test_pairs) == 0:
            print("Existing split is invalid for this dataset. Creating a new split.")
        else:
            return train_pairs, val_pairs, test_pairs

    rng = random.Random(CONFIG["random_seed"])
    pairs_copy = pairs[:]
    rng.shuffle(pairs_copy)

    n = len(pairs_copy)
    n_train = int(n * CONFIG["train_ratio"])
    n_val = int(n * CONFIG["val_ratio"])

    train_pairs = pairs_copy[:n_train]
    val_pairs = pairs_copy[n_train:n_train + n_val]
    test_pairs = pairs_copy[n_train + n_val:]

    with open(split_path, "w", encoding="utf-8") as f:
        json.dump(
            {
                "train": [x["stem"] for x in train_pairs],
                "val": [x["stem"] for x in val_pairs],
                "test": [x["stem"] for x in test_pairs],
            },
            f,
            indent=2,
            ensure_ascii=False
        )

    print("\nSaved new split:", split_path)
    return train_pairs, val_pairs, test_pairs


train_pairs, val_pairs, test_pairs = build_or_load_split(all_pairs, EXP_DIR)

print("\nSplit:")
print("Train:", len(train_pairs))
print("Val:", len(val_pairs))
print("Test:", len(test_pairs))


# ============================================================
# Dataset
# ============================================================

class Border128ToColor400Dataset(Dataset):
    def __init__(self, pairs, split_name: str, augment: bool):
        self.pairs = list(pairs)
        self.split_name = split_name
        self.augment = augment

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        item = self.pairs[idx]
        name = item["name"]

        border_img = load_border_image(
            item["border_path"],
            out_size=CONFIG["input_border_size"]
        )

        rgb_img, alpha_img = create_alpha_from_color_image(
            item["color_path"],
            out_size=CONFIG["output_color_size"],
            white_threshold=CONFIG["white_bg_threshold"]
        )

        if self.augment:
            rng = np.random.default_rng(
                CONFIG["random_seed"]
                + idx * 9973
                + random.randint(0, 10_000_000)
            )

            border_img, rgb_img, alpha_img = apply_shared_scaling(
                border_img,
                rgb_img,
                alpha_img,
                rng,
            )

            border_img = degrade_border_only(border_img, rng)

        border_tensor = pil_gray_mask_to_tensor(border_img)
        rgb_tensor = pil_rgb_to_tensor(rgb_img)
        alpha_tensor = pil_gray_mask_to_tensor(alpha_img)

        meta = {
            "name": name,
            "stem": item["stem"],
            "dataset_name": CONFIG["dataset_name"],
            "border_path": str(item["border_path"]),
            "color_path": str(item["color_path"]),
            "split": self.split_name,
        }

        return border_tensor, rgb_tensor, alpha_tensor, meta


train_dataset = Border128ToColor400Dataset(
    train_pairs,
    split_name="train",
    augment=CONFIG["use_train_augmentation"]
)

val_dataset = Border128ToColor400Dataset(
    val_pairs,
    split_name="val",
    augment=False
)

test_dataset = Border128ToColor400Dataset(
    test_pairs,
    split_name="test",
    augment=False
)


train_loader = DataLoader(
    train_dataset,
    batch_size=CONFIG["batch_size"],
    shuffle=True,
    num_workers=CONFIG["num_workers"],
    pin_memory=PIN_MEMORY,
    drop_last=False,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=CONFIG["batch_size"],
    shuffle=False,
    num_workers=CONFIG["num_workers"],
    pin_memory=PIN_MEMORY,
    drop_last=False,
)

test_loader = DataLoader(
    test_dataset,
    batch_size=CONFIG["batch_size"],
    shuffle=False,
    num_workers=CONFIG["num_workers"],
    pin_memory=PIN_MEMORY,
    drop_last=False,
)


# ============================================================
# Dataset visual check
# ============================================================

def show_dataset_samples(dataset, num_samples=6, seed=123, save_path=None):
    rng = np.random.default_rng(seed)
    idxs = rng.choice(len(dataset), size=min(num_samples, len(dataset)), replace=False)

    fig, axes = plt.subplots(len(idxs), 3, figsize=(11, 3.5 * len(idxs)))

    if len(idxs) == 1:
        axes = np.expand_dims(axes, axis=0)

    for row, idx in enumerate(idxs):
        border, rgb, alpha, meta = dataset[int(idx)]

        axes[row, 0].imshow(tensor_to_gray_numpy(border), cmap="gray", vmin=0, vmax=1)
        axes[row, 0].set_title(f"Input border 128\n{meta['dataset_name']} / {meta['name']}")
        axes[row, 0].axis("off")

        axes[row, 1].imshow(tensor_to_rgb_numpy(rgb))
        axes[row, 1].set_title("Target RGB 400")
        axes[row, 1].axis("off")

        axes[row, 2].imshow(tensor_to_gray_numpy(alpha), cmap="gray", vmin=0, vmax=1)
        axes[row, 2].set_title("Target Alpha 400")
        axes[row, 2].axis("off")

    plt.tight_layout()

    if save_path is not None:
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        print("Saved:", save_path)

    plt.show()


show_dataset_samples(
    train_dataset,
    num_samples=6,
    seed=123,
    save_path=SAMPLE_DIR / "dataset_debug_128to400_grape_new.png"
)


# ============================================================
# Model: 128 -> 400
# ============================================================

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.net = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),

            nn.Conv2d(out_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.net(x)


class UpBlockNoSkip(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(channels, channels, kernel_size=2, stride=2)
        self.conv = DoubleConv(channels, channels)

    def forward(self, x):
        x = self.up(x)
        x = self.conv(x)
        return x


class ResizeConvBlock(nn.Module):
    """
    256 -> 400 のような2倍ではない拡大をモデル内部で行うblock。
    後処理resizeではなく、decoderの一部として補間 + Convで学習させる。
    """
    def __init__(self, channels, out_size: int):
        super().__init__()
        self.out_size = out_size
        self.conv = DoubleConv(channels, channels)

    def forward(self, x):
        x = F.interpolate(
            x,
            size=(self.out_size, self.out_size),
            mode="bilinear",
            align_corners=False,
        )
        x = self.conv(x)
        return x


class UNetRGBA128To400(nn.Module):
    """
    Input:
      [B, 1, 128, 128]

    Output:
      [B, 4, 400, 400]
    """
    def __init__(self, in_channels=1, out_channels=4, base_channels=24):
        super().__init__()

        c1 = base_channels
        c2 = base_channels * 2
        c3 = base_channels * 4
        c4 = base_channels * 8

        self.enc1 = DoubleConv(in_channels, c1)
        self.pool1 = nn.MaxPool2d(2)

        self.enc2 = DoubleConv(c1, c2)
        self.pool2 = nn.MaxPool2d(2)

        self.enc3 = DoubleConv(c2, c3)
        self.pool3 = nn.MaxPool2d(2)

        self.bottleneck = DoubleConv(c3, c4)

        self.up3 = nn.ConvTranspose2d(c4, c3, kernel_size=2, stride=2)
        self.dec3 = DoubleConv(c3 + c3, c3)

        self.up2 = nn.ConvTranspose2d(c3, c2, kernel_size=2, stride=2)
        self.dec2 = DoubleConv(c2 + c2, c2)

        self.up1 = nn.ConvTranspose2d(c2, c1, kernel_size=2, stride=2)
        self.dec1 = DoubleConv(c1 + c1, c1)

        self.up0 = UpBlockNoSkip(c1)
        self.up_to_400 = ResizeConvBlock(c1, out_size=400)

        self.out_conv = nn.Conv2d(c1, out_channels, kernel_size=1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool1(e1))
        e3 = self.enc3(self.pool2(e2))

        b = self.bottleneck(self.pool3(e3))

        d3 = self.up3(b)
        d3 = torch.cat([d3, e3], dim=1)
        d3 = self.dec3(d3)

        d2 = self.up2(d3)
        d2 = torch.cat([d2, e2], dim=1)
        d2 = self.dec2(d2)

        d1 = self.up1(d2)
        d1 = torch.cat([d1, e1], dim=1)
        d1 = self.dec1(d1)

        d0 = self.up0(d1)
        d400 = self.up_to_400(d0)

        return self.out_conv(d400)


model = UNetRGBA128To400(
    in_channels=CONFIG["input_channels"],
    out_channels=CONFIG["output_channels"],
    base_channels=CONFIG["base_channels"]
).to(DEVICE)

print("\nModel:", model.__class__.__name__)
print("Trainable params:", sum(p.numel() for p in model.parameters() if p.requires_grad))


# ============================================================
# Loss
# ============================================================

def dice_loss_from_logits(logits, targets, eps=1e-6):
    probs = torch.sigmoid(logits)

    probs = probs.view(probs.size(0), -1)
    targets = targets.view(targets.size(0), -1)

    intersection = (probs * targets).sum(dim=1)
    denominator = probs.sum(dim=1) + targets.sum(dim=1)

    dice = (2.0 * intersection + eps) / (denominator + eps)
    return 1.0 - dice.mean()


def rgba_colorization_loss(output, rgb_target, alpha_target, eps=1e-6):
    rgb_logit = output[:, 0:3, :, :]
    alpha_logit = output[:, 3:4, :, :]

    rgb_pred = torch.sigmoid(rgb_logit)

    mask = alpha_target
    rgb_l1 = torch.abs(rgb_pred - rgb_target)
    rgb_inside_loss = (rgb_l1 * mask).sum() / (mask.sum() * 3.0 + eps)

    alpha_bce = F.binary_cross_entropy_with_logits(alpha_logit, alpha_target)
    alpha_dice = dice_loss_from_logits(alpha_logit, alpha_target, eps=eps)

    total = (
        CONFIG["rgb_loss_weight"] * rgb_inside_loss
        + CONFIG["alpha_bce_weight"] * alpha_bce
        + CONFIG["alpha_dice_weight"] * alpha_dice
    )

    bg_rgb_loss = torch.tensor(0.0, device=output.device)

    if CONFIG["background_rgb_weight"] > 0:
        bg_mask = 1.0 - alpha_target
        white = torch.ones_like(rgb_pred)

        bg_l1 = torch.abs(rgb_pred - white)
        bg_rgb_loss = (bg_l1 * bg_mask).sum() / (bg_mask.sum() * 3.0 + eps)

        total = total + CONFIG["background_rgb_weight"] * bg_rgb_loss

    return total, {
        "loss": total.detach(),
        "rgb_inside_loss": rgb_inside_loss.detach(),
        "alpha_bce": alpha_bce.detach(),
        "alpha_dice": alpha_dice.detach(),
        "bg_rgb_loss": bg_rgb_loss.detach(),
    }


# ============================================================
# Metrics
# ============================================================

@torch.no_grad()
def compute_batch_metrics(output, rgb_target, alpha_target, eps=1e-6):
    rgb_pred = torch.sigmoid(output[:, 0:3, :, :])
    alpha_prob = torch.sigmoid(output[:, 3:4, :, :])
    alpha_pred = (alpha_prob >= CONFIG["alpha_threshold"]).float()

    inter = (alpha_pred * alpha_target).sum(dim=(1, 2, 3))
    pred_sum = alpha_pred.sum(dim=(1, 2, 3))
    target_sum = alpha_target.sum(dim=(1, 2, 3))
    union = pred_sum + target_sum - inter

    alpha_dice = ((2.0 * inter + eps) / (pred_sum + target_sum + eps)).mean().item()
    alpha_iou = ((inter + eps) / (union + eps)).mean().item()

    mask = alpha_target
    rgb_mae_inside = (torch.abs(rgb_pred - rgb_target) * mask).sum() / (mask.sum() * 3.0 + eps)
    rgb_mae_inside = rgb_mae_inside.item()

    return {
        "alpha_dice": alpha_dice,
        "alpha_iou": alpha_iou,
        "rgb_mae_inside": rgb_mae_inside,
    }


# ============================================================
# Train / Eval functions
# ============================================================

def train_one_epoch(model, loader, optimizer, scaler):
    model.train()

    total = {
        "loss": 0.0,
        "rgb_inside_loss": 0.0,
        "alpha_bce": 0.0,
        "alpha_dice": 0.0,
        "bg_rgb_loss": 0.0,
        "alpha_dice_metric": 0.0,
        "alpha_iou_metric": 0.0,
        "rgb_mae_inside_metric": 0.0,
    }

    n_samples = 0

    pbar = tqdm(loader, desc="Train", leave=False)

    for border, rgb_target, alpha_target, meta in pbar:
        border = border.to(DEVICE, non_blocking=True)
        rgb_target = rgb_target.to(DEVICE, non_blocking=True)
        alpha_target = alpha_target.to(DEVICE, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(
            "cuda",
            enabled=(CONFIG["use_amp"] and DEVICE.type == "cuda")
        ):
            output = model(border)
            loss, loss_dict = rgba_colorization_loss(output, rgb_target, alpha_target)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        metrics = compute_batch_metrics(output, rgb_target, alpha_target)

        bs = border.size(0)
        n_samples += bs

        total["loss"] += loss_dict["loss"].item() * bs
        total["rgb_inside_loss"] += loss_dict["rgb_inside_loss"].item() * bs
        total["alpha_bce"] += loss_dict["alpha_bce"].item() * bs
        total["alpha_dice"] += loss_dict["alpha_dice"].item() * bs
        total["bg_rgb_loss"] += loss_dict["bg_rgb_loss"].item() * bs

        total["alpha_dice_metric"] += metrics["alpha_dice"] * bs
        total["alpha_iou_metric"] += metrics["alpha_iou"] * bs
        total["rgb_mae_inside_metric"] += metrics["rgb_mae_inside"] * bs

        pbar.set_postfix({
            "loss": f"{loss_dict['loss'].item():.4f}",
            "rgb": f"{loss_dict['rgb_inside_loss'].item():.4f}",
            "a_bce": f"{loss_dict['alpha_bce'].item():.4f}",
            "a_dice": f"{loss_dict['alpha_dice'].item():.4f}",
        })

    for k in total:
        total[k] /= max(n_samples, 1)

    return total


@torch.no_grad()
def evaluate(model, loader):
    model.eval()

    total = {
        "loss": 0.0,
        "rgb_inside_loss": 0.0,
        "alpha_bce": 0.0,
        "alpha_dice": 0.0,
        "bg_rgb_loss": 0.0,
        "alpha_dice_metric": 0.0,
        "alpha_iou_metric": 0.0,
        "rgb_mae_inside_metric": 0.0,
    }

    n_samples = 0

    for border, rgb_target, alpha_target, meta in tqdm(loader, desc="Eval", leave=False):
        border = border.to(DEVICE, non_blocking=True)
        rgb_target = rgb_target.to(DEVICE, non_blocking=True)
        alpha_target = alpha_target.to(DEVICE, non_blocking=True)

        output = model(border)
        loss, loss_dict = rgba_colorization_loss(output, rgb_target, alpha_target)
        metrics = compute_batch_metrics(output, rgb_target, alpha_target)

        bs = border.size(0)
        n_samples += bs

        total["loss"] += loss_dict["loss"].item() * bs
        total["rgb_inside_loss"] += loss_dict["rgb_inside_loss"].item() * bs
        total["alpha_bce"] += loss_dict["alpha_bce"].item() * bs
        total["alpha_dice"] += loss_dict["alpha_dice"].item() * bs
        total["bg_rgb_loss"] += loss_dict["bg_rgb_loss"].item() * bs

        total["alpha_dice_metric"] += metrics["alpha_dice"] * bs
        total["alpha_iou_metric"] += metrics["alpha_iou"] * bs
        total["rgb_mae_inside_metric"] += metrics["rgb_mae_inside"] * bs

    for k in total:
        total[k] /= max(n_samples, 1)

    return total


# ============================================================
# Sample saving
# ============================================================

@torch.no_grad()
def save_validation_samples(
    model,
    dataset,
    epoch,
    save_dir,
    num_samples=6,
    seed=123
):
    model.eval()

    if len(dataset) == 0:
        return None

    rng = np.random.default_rng(seed + epoch)
    idxs = rng.choice(len(dataset), size=min(num_samples, len(dataset)), replace=False)

    fig, axes = plt.subplots(len(idxs), 6, figsize=(22, 3.6 * len(idxs)))

    if len(idxs) == 1:
        axes = np.expand_dims(axes, axis=0)

    for row, idx in enumerate(idxs):
        border, rgb_target, alpha_target, meta = dataset[int(idx)]

        x = border.unsqueeze(0).to(DEVICE)
        output = model(x)

        rgb_pred = torch.sigmoid(output[:, 0:3])[0].cpu()
        alpha_pred = torch.sigmoid(output[:, 3:4])[0].cpu()
        alpha_bin = (alpha_pred >= CONFIG["alpha_threshold"]).float()

        border_np = tensor_to_gray_numpy(border)
        rgb_target_np = tensor_to_rgb_numpy(rgb_target)
        alpha_target_np = tensor_to_gray_numpy(alpha_target)

        rgb_pred_np = tensor_to_rgb_numpy(rgb_pred)
        alpha_pred_np = tensor_to_gray_numpy(alpha_pred)
        composite_np = alpha_composite_on_checker(
            rgb_pred_np,
            tensor_to_gray_numpy(alpha_bin)
        )

        axes[row, 0].imshow(border_np, cmap="gray", vmin=0, vmax=1)
        axes[row, 0].set_title(f"Input border 128\n{meta['dataset_name']} / {meta['name']}")
        axes[row, 0].axis("off")

        axes[row, 1].imshow(rgb_target_np)
        axes[row, 1].set_title("GT RGB 400")
        axes[row, 1].axis("off")

        axes[row, 2].imshow(alpha_target_np, cmap="gray", vmin=0, vmax=1)
        axes[row, 2].set_title("GT Alpha 400")
        axes[row, 2].axis("off")

        axes[row, 3].imshow(rgb_pred_np)
        axes[row, 3].set_title("Pred RGB 400")
        axes[row, 3].axis("off")

        axes[row, 4].imshow(alpha_pred_np, cmap="gray", vmin=0, vmax=1)
        axes[row, 4].set_title("Pred Alpha 400")
        axes[row, 4].axis("off")

        axes[row, 5].imshow(composite_np)
        axes[row, 5].set_title("Pred RGBA checker")
        axes[row, 5].axis("off")

    plt.tight_layout()

    save_path = Path(save_dir) / f"epoch_{epoch:03d}.png"
    plt.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.close()

    return save_path


# ============================================================
# Optimizer / Scheduler / AMP
# ============================================================

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=CONFIG["learning_rate"],
    weight_decay=CONFIG["weight_decay"]
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=5
)

scaler = torch.amp.GradScaler(
    "cuda",
    enabled=(CONFIG["use_amp"] and DEVICE.type == "cuda")
)

print("\nPreparation done.")
print("Ready for main training loop.")
print("Dataset name:", DATASET_NAME)
print("Experiment dir:", EXP_DIR)


# ============================================================
# Main training loop
# 128x128 input -> 400x400 RGBA output
# ============================================================

best_val_loss = float("inf")
best_epoch = -1
patience_counter = 0

log_path = LOG_DIR / "train_log.csv"

with open(log_path, "w", encoding="utf-8") as f:
    f.write(
        "epoch,"
        "train_loss,train_rgb_inside_loss,train_alpha_bce,train_alpha_dice,"
        "train_alpha_dice_metric,train_alpha_iou_metric,train_rgb_mae_inside_metric,"
        "val_loss,val_rgb_inside_loss,val_alpha_bce,val_alpha_dice,"
        "val_alpha_dice_metric,val_alpha_iou_metric,val_rgb_mae_inside_metric,"
        "lr\n"
    )

for epoch in range(1, CONFIG["epochs"] + 1):
    print(f"\nEpoch {epoch}/{CONFIG['epochs']}")

    train_metrics = train_one_epoch(model, train_loader, optimizer, scaler)
    val_metrics = evaluate(model, val_loader)

    scheduler.step(val_metrics["loss"])
    current_lr = optimizer.param_groups[0]["lr"]

    print(
        f"Train loss: {train_metrics['loss']:.5f} | "
        f"Train RGB: {train_metrics['rgb_inside_loss']:.5f} | "
        f"Train Alpha BCE: {train_metrics['alpha_bce']:.5f} | "
        f"Train Alpha DiceLoss: {train_metrics['alpha_dice']:.5f} | "
        f"Train Alpha Dice: {train_metrics['alpha_dice_metric']:.5f} | "
        f"Train Alpha IoU: {train_metrics['alpha_iou_metric']:.5f} | "
        f"Train RGB MAE(in): {train_metrics['rgb_mae_inside_metric']:.5f}"
    )

    print(
        f"Val loss: {val_metrics['loss']:.5f} | "
        f"Val RGB: {val_metrics['rgb_inside_loss']:.5f} | "
        f"Val Alpha BCE: {val_metrics['alpha_bce']:.5f} | "
        f"Val Alpha DiceLoss: {val_metrics['alpha_dice']:.5f} | "
        f"Val Alpha Dice: {val_metrics['alpha_dice_metric']:.5f} | "
        f"Val Alpha IoU: {val_metrics['alpha_iou_metric']:.5f} | "
        f"Val RGB MAE(in): {val_metrics['rgb_mae_inside_metric']:.5f} | "
        f"LR: {current_lr:.6f}"
    )

    with open(log_path, "a", encoding="utf-8") as f:
        f.write(
            f"{epoch},"
            f"{train_metrics['loss']:.8f},{train_metrics['rgb_inside_loss']:.8f},{train_metrics['alpha_bce']:.8f},{train_metrics['alpha_dice']:.8f},"
            f"{train_metrics['alpha_dice_metric']:.8f},{train_metrics['alpha_iou_metric']:.8f},{train_metrics['rgb_mae_inside_metric']:.8f},"
            f"{val_metrics['loss']:.8f},{val_metrics['rgb_inside_loss']:.8f},{val_metrics['alpha_bce']:.8f},{val_metrics['alpha_dice']:.8f},"
            f"{val_metrics['alpha_dice_metric']:.8f},{val_metrics['alpha_iou_metric']:.8f},{val_metrics['rgb_mae_inside_metric']:.8f},"
            f"{current_lr:.10f}\n"
        )

    sample_path = save_validation_samples(
        model=model,
        dataset=val_dataset,
        epoch=epoch,
        save_dir=SAMPLE_DIR,
        num_samples=6,
        seed=123,
    )
    print("Saved sample:", sample_path)

    last_checkpoint = {
        "epoch": epoch,
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "scheduler_state_dict": scheduler.state_dict(),
        "scaler_state_dict": scaler.state_dict(),
        "train_metrics": train_metrics,
        "val_metrics": val_metrics,
        "config": CONFIG,
    }

    torch.save(last_checkpoint, CHECKPOINT_DIR / "last_model.pt")

    if val_metrics["loss"] < best_val_loss:
        best_val_loss = val_metrics["loss"]
        best_epoch = epoch
        patience_counter = 0

        best_checkpoint = {
            "epoch": epoch,
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict(),
            "scaler_state_dict": scaler.state_dict(),
            "train_metrics": train_metrics,
            "val_metrics": val_metrics,
            "config": CONFIG,
        }

        torch.save(best_checkpoint, CHECKPOINT_DIR / "best_model.pt")
        print(f"Best model updated. best_val_loss={best_val_loss:.5f}")

    else:
        patience_counter += 1
        print(f"No improvement. patience={patience_counter}/{CONFIG['early_stopping_patience']}")

    if patience_counter >= CONFIG["early_stopping_patience"]:
        print("Early stopping.")
        break

print(f"\nTraining finished. Best epoch: {best_epoch}, Best val loss: {best_val_loss:.5f}")


# ============================================================
# Load best model and evaluate on test set
# ============================================================

best_model_path = CHECKPOINT_DIR / "best_model.pt"

if not best_model_path.exists():
    raise FileNotFoundError(f"Best model not found: {best_model_path}")

checkpoint = torch.load(best_model_path, map_location=DEVICE)

model.load_state_dict(checkpoint["model_state_dict"])
model.to(DEVICE)
model.eval()

test_metrics = evaluate(model, test_loader)

print("\nTest metrics:")
for k, v in test_metrics.items():
    print(f"{k}: {v:.6f}")

with open(EXP_DIR / "test_metrics.json", "w", encoding="utf-8") as f:
    json.dump(test_metrics, f, indent=2, ensure_ascii=False)

test_sample_path = save_validation_samples(
    model=model,
    dataset=test_dataset,
    epoch=999,
    save_dir=SAMPLE_DIR,
    num_samples=6,
    seed=999,
)

print("Saved test sample:", test_sample_path)
print("Best model path:", best_model_path)
print("Log path:", log_path)
# Out:
# Mounted at /content/drive
# DEVICE: cuda
# CUDA available: True
# GPU: Tesla T4
# Extracting color.zip...
# Extracted to: /content/grape_new_color_data_128to400
#
# Extracted top-level:
#   /content/grape_new_color_data_128to400/__MACOSX
#   /content/grape_new_color_data_128to400/color
#
# Found ('border_dataset', 'grape_new'): /content/grape_new_color_data_128to400/color/border_dataset/grape_new
# Image count: 960
#
# Found ('color_dataset', 'grape_new'): /content/grape_new_color_data_128to400/color/color_dataset/grape_new
# Image count: 960
#
# Final dataset dirs:
# BORDER_DIR: /content/grape_new_color_data_128to400/color/border_dataset/grape_new
# COLOR_DIR: /content/grape_new_color_data_128to400/color/color_dataset/grape_new
#
# Border files found: 960
# Color files found: 960
# Border examples: ['1.png', '10.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png']
# Color examples: ['1.png', '10.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png']
# Matched pairs: 960
# Missing in color: 0
# Missing in border: 0
#
# Saved new split: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/split.json
#
# Split:
# Train: 768
# Val: 96
# Test: 96
# Saved: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/dataset_debug_128to400_grape_new.png
# Model: UNetRGBA128To400
# Trainable params: 1107580
#
# Preparation done.
# Ready for main training loop.
# Dataset name: grape_new
# Experiment dir: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001
#
# Epoch 1/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.71432 | Train RGB: 0.18563 | Train Alpha BCE: 0.28112 | Train Alpha DiceLoss: 0.50506 | Train Alpha Dice: 0.79530 | Train Alpha IoU: 0.68805 | Train RGB MAE(in): 0.18563
# Val loss: 1.99390 | Val RGB: 0.17702 | Val Alpha BCE: 0.53617 | Val Alpha DiceLoss: 0.57264 | Val Alpha Dice: 0.50811 | Val Alpha IoU: 0.34303 | Val RGB MAE(in): 0.17702 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_001.png
# Best model updated. best_val_loss=1.99390
#
# Epoch 2/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.31944 | Train RGB: 0.17742 | Train Alpha BCE: 0.13749 | Train Alpha DiceLoss: 0.29487 | Train Alpha Dice: 0.85705 | Train Alpha IoU: 0.75939 | Train RGB MAE(in): 0.17742
# Val loss: 1.97497 | Val RGB: 0.17461 | Val Alpha BCE: 0.56811 | Val Alpha DiceLoss: 0.53382 | Val Alpha Dice: 0.49249 | Val Alpha IoU: 0.32812 | Val RGB MAE(in): 0.17461 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_002.png
# Best model updated. best_val_loss=1.97497
#
# Epoch 3/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.19506 | Train RGB: 0.17605 | Train Alpha BCE: 0.10720 | Train Alpha DiceLoss: 0.20762 | Train Alpha Dice: 0.86567 | Train Alpha IoU: 0.77265 | Train RGB MAE(in): 0.17605
# Val loss: 1.19735 | Val RGB: 0.17480 | Val Alpha BCE: 0.10719 | Val Alpha DiceLoss: 0.21618 | Val Alpha Dice: 0.86929 | Val Alpha IoU: 0.77461 | Val RGB MAE(in): 0.17480 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_003.png
# Best model updated. best_val_loss=1.19735
#
# Epoch 4/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.16091 | Train RGB: 0.17521 | Train Alpha BCE: 0.10278 | Train Alpha DiceLoss: 0.18207 | Train Alpha Dice: 0.86308 | Train Alpha IoU: 0.77036 | Train RGB MAE(in): 0.17521
# Val loss: 1.14011 | Val RGB: 0.17722 | Val Alpha BCE: 0.09437 | Val Alpha DiceLoss: 0.15967 | Val Alpha Dice: 0.87562 | Val Alpha IoU: 0.78247 | Val RGB MAE(in): 0.17722 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_004.png
# Best model updated. best_val_loss=1.14011
#
# Epoch 5/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.12250 | Train RGB: 0.17391 | Train Alpha BCE: 0.09253 | Train Alpha DiceLoss: 0.16040 | Train Alpha Dice: 0.87417 | Train Alpha IoU: 0.78405 | Train RGB MAE(in): 0.17391
# Val loss: 1.07146 | Val RGB: 0.17119 | Val Alpha BCE: 0.08076 | Val Alpha DiceLoss: 0.13475 | Val Alpha Dice: 0.89065 | Val Alpha IoU: 0.80597 | Val RGB MAE(in): 0.17119 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_005.png
# Best model updated. best_val_loss=1.07146
#
# Epoch 6/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.10442 | Train RGB: 0.17298 | Train Alpha BCE: 0.08806 | Train Alpha DiceLoss: 0.15145 | Train Alpha Dice: 0.87708 | Train Alpha IoU: 0.78815 | Train RGB MAE(in): 0.17298
# Val loss: 1.06351 | Val RGB: 0.17159 | Val Alpha BCE: 0.07552 | Val Alpha DiceLoss: 0.13004 | Val Alpha Dice: 0.89510 | Val Alpha IoU: 0.81232 | Val RGB MAE(in): 0.17159 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_006.png
# Best model updated. best_val_loss=1.06351
#
# Epoch 7/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.09503 | Train RGB: 0.17316 | Train Alpha BCE: 0.08474 | Train Alpha DiceLoss: 0.14449 | Train Alpha Dice: 0.88087 | Train Alpha IoU: 0.79361 | Train RGB MAE(in): 0.17316
# Val loss: 1.61206 | Val RGB: 0.17223 | Val Alpha BCE: 0.36653 | Val Alpha DiceLoss: 0.38439 | Val Alpha Dice: 0.63766 | Val Alpha IoU: 0.47247 | Val RGB MAE(in): 0.17223 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_007.png
# No improvement. patience=1/15
#
# Epoch 8/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.09712 | Train RGB: 0.17305 | Train Alpha BCE: 0.08664 | Train Alpha DiceLoss: 0.14525 | Train Alpha Dice: 0.87767 | Train Alpha IoU: 0.78933 | Train RGB MAE(in): 0.17305
# Val loss: 1.09641 | Val RGB: 0.17216 | Val Alpha BCE: 0.09442 | Val Alpha DiceLoss: 0.14117 | Val Alpha Dice: 0.87229 | Val Alpha IoU: 0.77671 | Val RGB MAE(in): 0.17216 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_008.png
# No improvement. patience=2/15
#
# Epoch 9/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.08026 | Train RGB: 0.17170 | Train Alpha BCE: 0.08303 | Train Alpha DiceLoss: 0.13873 | Train Alpha Dice: 0.88301 | Train Alpha IoU: 0.79645 | Train RGB MAE(in): 0.17170
# Val loss: 1.05671 | Val RGB: 0.17029 | Val Alpha BCE: 0.07305 | Val Alpha DiceLoss: 0.13221 | Val Alpha Dice: 0.89649 | Val Alpha IoU: 0.81405 | Val RGB MAE(in): 0.17029 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_009.png
# Best model updated. best_val_loss=1.05671
#
# Epoch 10/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.06963 | Train RGB: 0.17139 | Train Alpha BCE: 0.08029 | Train Alpha DiceLoss: 0.13238 | Train Alpha Dice: 0.88775 | Train Alpha IoU: 0.80288 | Train RGB MAE(in): 0.17139
# Val loss: 1.05289 | Val RGB: 0.17163 | Val Alpha BCE: 0.07332 | Val Alpha DiceLoss: 0.12141 | Val Alpha Dice: 0.89950 | Val Alpha IoU: 0.81888 | Val RGB MAE(in): 0.17163 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_010.png
# Best model updated. best_val_loss=1.05289
#
# Epoch 11/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.07277 | Train RGB: 0.17144 | Train Alpha BCE: 0.08094 | Train Alpha DiceLoss: 0.13462 | Train Alpha Dice: 0.88576 | Train Alpha IoU: 0.79970 | Train RGB MAE(in): 0.17144
# Val loss: 1.02342 | Val RGB: 0.16785 | Val Alpha BCE: 0.06622 | Val Alpha DiceLoss: 0.11793 | Val Alpha Dice: 0.90230 | Val Alpha IoU: 0.82405 | Val RGB MAE(in): 0.16785 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_011.png
# Best model updated. best_val_loss=1.02342
#
# Epoch 12/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.06478 | Train RGB: 0.17075 | Train Alpha BCE: 0.07952 | Train Alpha DiceLoss: 0.13153 | Train Alpha Dice: 0.88797 | Train Alpha IoU: 0.80298 | Train RGB MAE(in): 0.17075
# Val loss: 1.05855 | Val RGB: 0.17431 | Val Alpha BCE: 0.07350 | Val Alpha DiceLoss: 0.11350 | Val Alpha Dice: 0.90264 | Val Alpha IoU: 0.82465 | Val RGB MAE(in): 0.17431 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_012.png
# No improvement. patience=1/15
#
# Epoch 13/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.06366 | Train RGB: 0.17046 | Train Alpha BCE: 0.07918 | Train Alpha DiceLoss: 0.13218 | Train Alpha Dice: 0.88668 | Train Alpha IoU: 0.80237 | Train RGB MAE(in): 0.17046
# Val loss: 1.02150 | Val RGB: 0.16825 | Val Alpha BCE: 0.07230 | Val Alpha DiceLoss: 0.10795 | Val Alpha Dice: 0.90442 | Val Alpha IoU: 0.82762 | Val RGB MAE(in): 0.16825 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_013.png
# Best model updated. best_val_loss=1.02150
#
# Epoch 14/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.06393 | Train RGB: 0.17031 | Train Alpha BCE: 0.08023 | Train Alpha DiceLoss: 0.13213 | Train Alpha Dice: 0.88595 | Train Alpha IoU: 0.80107 | Train RGB MAE(in): 0.17031
# Val loss: 1.04702 | Val RGB: 0.17167 | Val Alpha BCE: 0.06522 | Val Alpha DiceLoss: 0.12347 | Val Alpha Dice: 0.90297 | Val Alpha IoU: 0.82438 | Val RGB MAE(in): 0.17167 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_014.png
# No improvement. patience=1/15
#
# Epoch 15/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.05204 | Train RGB: 0.16961 | Train Alpha BCE: 0.07687 | Train Alpha DiceLoss: 0.12711 | Train Alpha Dice: 0.89097 | Train Alpha IoU: 0.80743 | Train RGB MAE(in): 0.16961
# Val loss: 1.26281 | Val RGB: 0.17983 | Val Alpha BCE: 0.14886 | Val Alpha DiceLoss: 0.21480 | Val Alpha Dice: 0.80204 | Val Alpha IoU: 0.67276 | Val RGB MAE(in): 0.17983 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_015.png
# No improvement. patience=2/15
#
# Epoch 16/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.05664 | Train RGB: 0.17001 | Train Alpha BCE: 0.07817 | Train Alpha DiceLoss: 0.12842 | Train Alpha Dice: 0.88991 | Train Alpha IoU: 0.80602 | Train RGB MAE(in): 0.17001
# Val loss: 1.01092 | Val RGB: 0.16653 | Val Alpha BCE: 0.06416 | Val Alpha DiceLoss: 0.11413 | Val Alpha Dice: 0.90410 | Val Alpha IoU: 0.82666 | Val RGB MAE(in): 0.16653 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_016.png
# Best model updated. best_val_loss=1.01092
#
# Epoch 17/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.04908 | Train RGB: 0.16924 | Train Alpha BCE: 0.07705 | Train Alpha DiceLoss: 0.12585 | Train Alpha Dice: 0.89184 | Train Alpha IoU: 0.80956 | Train RGB MAE(in): 0.16924
# Val loss: 1.02218 | Val RGB: 0.16865 | Val Alpha BCE: 0.06938 | Val Alpha DiceLoss: 0.10956 | Val Alpha Dice: 0.90323 | Val Alpha IoU: 0.82563 | Val RGB MAE(in): 0.16865 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_017.png
# No improvement. patience=1/15
#
# Epoch 18/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.04366 | Train RGB: 0.16865 | Train Alpha BCE: 0.07598 | Train Alpha DiceLoss: 0.12443 | Train Alpha Dice: 0.89282 | Train Alpha IoU: 0.81066 | Train RGB MAE(in): 0.16865
# Val loss: 1.02349 | Val RGB: 0.16878 | Val Alpha BCE: 0.07043 | Val Alpha DiceLoss: 0.10916 | Val Alpha Dice: 0.90337 | Val Alpha IoU: 0.82624 | Val RGB MAE(in): 0.16878 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_018.png
# No improvement. patience=2/15
#
# Epoch 19/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.04710 | Train RGB: 0.16897 | Train Alpha BCE: 0.07683 | Train Alpha DiceLoss: 0.12544 | Train Alpha Dice: 0.89169 | Train Alpha IoU: 0.80926 | Train RGB MAE(in): 0.16897
# Val loss: 1.09572 | Val RGB: 0.17247 | Val Alpha BCE: 0.10087 | Val Alpha DiceLoss: 0.13249 | Val Alpha Dice: 0.87596 | Val Alpha IoU: 0.78219 | Val RGB MAE(in): 0.17247 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_019.png
# No improvement. patience=3/15
#
# Epoch 20/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.03410 | Train RGB: 0.16848 | Train Alpha BCE: 0.07258 | Train Alpha DiceLoss: 0.11913 | Train Alpha Dice: 0.89742 | Train Alpha IoU: 0.81708 | Train RGB MAE(in): 0.16848
# Val loss: 0.99375 | Val RGB: 0.16519 | Val Alpha BCE: 0.06042 | Val Alpha DiceLoss: 0.10739 | Val Alpha Dice: 0.91011 | Val Alpha IoU: 0.83640 | Val RGB MAE(in): 0.16519 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_020.png
# Best model updated. best_val_loss=0.99375
#
# Epoch 21/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.03125 | Train RGB: 0.16782 | Train Alpha BCE: 0.07275 | Train Alpha DiceLoss: 0.11940 | Train Alpha Dice: 0.89678 | Train Alpha IoU: 0.81695 | Train RGB MAE(in): 0.16782
# Val loss: 1.03223 | Val RGB: 0.17323 | Val Alpha BCE: 0.06185 | Val Alpha DiceLoss: 0.10423 | Val Alpha Dice: 0.91010 | Val Alpha IoU: 0.83639 | Val RGB MAE(in): 0.17323 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_021.png
# No improvement. patience=1/15
#
# Epoch 22/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.03092 | Train RGB: 0.16811 | Train Alpha BCE: 0.07234 | Train Alpha DiceLoss: 0.11802 | Train Alpha Dice: 0.89811 | Train Alpha IoU: 0.81840 | Train RGB MAE(in): 0.16811
# Val loss: 0.99841 | Val RGB: 0.16581 | Val Alpha BCE: 0.06556 | Val Alpha DiceLoss: 0.10380 | Val Alpha Dice: 0.91072 | Val Alpha IoU: 0.83712 | Val RGB MAE(in): 0.16581 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_022.png
# No improvement. patience=2/15
#
# Epoch 23/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.02792 | Train RGB: 0.16725 | Train Alpha BCE: 0.07243 | Train Alpha DiceLoss: 0.11921 | Train Alpha Dice: 0.89684 | Train Alpha IoU: 0.81781 | Train RGB MAE(in): 0.16725
# Val loss: 1.02820 | Val RGB: 0.17013 | Val Alpha BCE: 0.06603 | Val Alpha DiceLoss: 0.11151 | Val Alpha Dice: 0.90581 | Val Alpha IoU: 0.82906 | Val RGB MAE(in): 0.17013 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_023.png
# No improvement. patience=3/15
#
# Epoch 24/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.02593 | Train RGB: 0.16668 | Train Alpha BCE: 0.07298 | Train Alpha DiceLoss: 0.11955 | Train Alpha Dice: 0.89667 | Train Alpha IoU: 0.81772 | Train RGB MAE(in): 0.16668
# Val loss: 1.03462 | Val RGB: 0.17045 | Val Alpha BCE: 0.07045 | Val Alpha DiceLoss: 0.11194 | Val Alpha Dice: 0.90318 | Val Alpha IoU: 0.82465 | Val RGB MAE(in): 0.17045 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_024.png
# No improvement. patience=4/15
#
# Epoch 25/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.01979 | Train RGB: 0.16631 | Train Alpha BCE: 0.07168 | Train Alpha DiceLoss: 0.11658 | Train Alpha Dice: 0.89864 | Train Alpha IoU: 0.82115 | Train RGB MAE(in): 0.16631
# Val loss: 1.03369 | Val RGB: 0.17059 | Val Alpha BCE: 0.06740 | Val Alpha DiceLoss: 0.11332 | Val Alpha Dice: 0.90228 | Val Alpha IoU: 0.82341 | Val RGB MAE(in): 0.17059 | LR: 0.001000
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_025.png
# No improvement. patience=5/15
#
# Epoch 26/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 1.00447 | Train RGB: 0.16510 | Train Alpha BCE: 0.06825 | Train Alpha DiceLoss: 0.11073 | Train Alpha Dice: 0.90445 | Train Alpha IoU: 0.82914 | Train RGB MAE(in): 0.16510
# Val loss: 1.05719 | Val RGB: 0.17265 | Val Alpha BCE: 0.07601 | Val Alpha DiceLoss: 0.11791 | Val Alpha Dice: 0.89604 | Val Alpha IoU: 0.81266 | Val RGB MAE(in): 0.17265 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_026.png
# No improvement. patience=6/15
#
# Epoch 27/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.99383 | Train RGB: 0.16365 | Train Alpha BCE: 0.06626 | Train Alpha DiceLoss: 0.10934 | Train Alpha Dice: 0.90592 | Train Alpha IoU: 0.83198 | Train RGB MAE(in): 0.16365
# Val loss: 0.97730 | Val RGB: 0.16324 | Val Alpha BCE: 0.06055 | Val Alpha DiceLoss: 0.10056 | Val Alpha Dice: 0.91419 | Val Alpha IoU: 0.84337 | Val RGB MAE(in): 0.16324 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_027.png
# Best model updated. best_val_loss=0.97730
#
# Epoch 28/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.98040 | Train RGB: 0.16260 | Train Alpha BCE: 0.06337 | Train Alpha DiceLoss: 0.10404 | Train Alpha Dice: 0.91064 | Train Alpha IoU: 0.83925 | Train RGB MAE(in): 0.16260
# Val loss: 0.97854 | Val RGB: 0.16493 | Val Alpha BCE: 0.05921 | Val Alpha DiceLoss: 0.09467 | Val Alpha Dice: 0.91797 | Val Alpha IoU: 0.84980 | Val RGB MAE(in): 0.16493 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_028.png
# No improvement. patience=1/15
#
# Epoch 29/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.98146 | Train RGB: 0.16228 | Train Alpha BCE: 0.06468 | Train Alpha DiceLoss: 0.10540 | Train Alpha Dice: 0.90907 | Train Alpha IoU: 0.83690 | Train RGB MAE(in): 0.16228
# Val loss: 0.95200 | Val RGB: 0.16130 | Val Alpha BCE: 0.05576 | Val Alpha DiceLoss: 0.08974 | Val Alpha Dice: 0.92244 | Val Alpha IoU: 0.85721 | Val RGB MAE(in): 0.16130 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_029.png
# Best model updated. best_val_loss=0.95200
#
# Epoch 30/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.98219 | Train RGB: 0.16172 | Train Alpha BCE: 0.06579 | Train Alpha DiceLoss: 0.10778 | Train Alpha Dice: 0.90693 | Train Alpha IoU: 0.83407 | Train RGB MAE(in): 0.16172
# Val loss: 0.96226 | Val RGB: 0.16178 | Val Alpha BCE: 0.05727 | Val Alpha DiceLoss: 0.09611 | Val Alpha Dice: 0.91864 | Val Alpha IoU: 0.85050 | Val RGB MAE(in): 0.16178 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_030.png
# No improvement. patience=1/15
#
# Epoch 31/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.96269 | Train RGB: 0.16016 | Train Alpha BCE: 0.06130 | Train Alpha DiceLoss: 0.10059 | Train Alpha Dice: 0.91325 | Train Alpha IoU: 0.84363 | Train RGB MAE(in): 0.16016
# Val loss: 0.93872 | Val RGB: 0.15878 | Val Alpha BCE: 0.05568 | Val Alpha DiceLoss: 0.08914 | Val Alpha Dice: 0.92315 | Val Alpha IoU: 0.85841 | Val RGB MAE(in): 0.15878 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_031.png
# Best model updated. best_val_loss=0.93872
#
# Epoch 32/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.96727 | Train RGB: 0.16059 | Train Alpha BCE: 0.06242 | Train Alpha DiceLoss: 0.10191 | Train Alpha Dice: 0.91189 | Train Alpha IoU: 0.84198 | Train RGB MAE(in): 0.16059
# Val loss: 0.96309 | Val RGB: 0.16107 | Val Alpha BCE: 0.06189 | Val Alpha DiceLoss: 0.09587 | Val Alpha Dice: 0.91537 | Val Alpha IoU: 0.84534 | Val RGB MAE(in): 0.16107 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_032.png
# No improvement. patience=1/15
#
# Epoch 33/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.96283 | Train RGB: 0.15988 | Train Alpha BCE: 0.06238 | Train Alpha DiceLoss: 0.10104 | Train Alpha Dice: 0.91286 | Train Alpha IoU: 0.84315 | Train RGB MAE(in): 0.15988
# Val loss: 0.96782 | Val RGB: 0.16181 | Val Alpha BCE: 0.06441 | Val Alpha DiceLoss: 0.09436 | Val Alpha Dice: 0.91588 | Val Alpha IoU: 0.84646 | Val RGB MAE(in): 0.16181 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_033.png
# No improvement. patience=2/15
#
# Epoch 34/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.95114 | Train RGB: 0.15858 | Train Alpha BCE: 0.06010 | Train Alpha DiceLoss: 0.09813 | Train Alpha Dice: 0.91525 | Train Alpha IoU: 0.84746 | Train RGB MAE(in): 0.15858
# Val loss: 0.93658 | Val RGB: 0.15829 | Val Alpha BCE: 0.05545 | Val Alpha DiceLoss: 0.08965 | Val Alpha Dice: 0.92275 | Val Alpha IoU: 0.85777 | Val RGB MAE(in): 0.15829 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_034.png
# Best model updated. best_val_loss=0.93658
#
# Epoch 35/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.94525 | Train RGB: 0.15800 | Train Alpha BCE: 0.05916 | Train Alpha DiceLoss: 0.09610 | Train Alpha Dice: 0.91737 | Train Alpha IoU: 0.85059 | Train RGB MAE(in): 0.15800
# Val loss: 0.94906 | Val RGB: 0.16063 | Val Alpha BCE: 0.05707 | Val Alpha DiceLoss: 0.08884 | Val Alpha Dice: 0.92210 | Val Alpha IoU: 0.85650 | Val RGB MAE(in): 0.16063 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_035.png
# No improvement. patience=1/15
#
# Epoch 36/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.94045 | Train RGB: 0.15695 | Train Alpha BCE: 0.05915 | Train Alpha DiceLoss: 0.09653 | Train Alpha Dice: 0.91674 | Train Alpha IoU: 0.85091 | Train RGB MAE(in): 0.15695
# Val loss: 0.95593 | Val RGB: 0.16101 | Val Alpha BCE: 0.05888 | Val Alpha DiceLoss: 0.09199 | Val Alpha Dice: 0.91940 | Val Alpha IoU: 0.85209 | Val RGB MAE(in): 0.16101 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_036.png
# No improvement. patience=2/15
#
# Epoch 37/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.93731 | Train RGB: 0.15677 | Train Alpha BCE: 0.05873 | Train Alpha DiceLoss: 0.09472 | Train Alpha Dice: 0.91815 | Train Alpha IoU: 0.85278 | Train RGB MAE(in): 0.15677
# Val loss: 0.93053 | Val RGB: 0.15750 | Val Alpha BCE: 0.05626 | Val Alpha DiceLoss: 0.08679 | Val Alpha Dice: 0.92371 | Val Alpha IoU: 0.85917 | Val RGB MAE(in): 0.15750 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_037.png
# Best model updated. best_val_loss=0.93053
#
# Epoch 38/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.93798 | Train RGB: 0.15660 | Train Alpha BCE: 0.05906 | Train Alpha DiceLoss: 0.09591 | Train Alpha Dice: 0.91709 | Train Alpha IoU: 0.85068 | Train RGB MAE(in): 0.15660
# Val loss: 0.94639 | Val RGB: 0.15966 | Val Alpha BCE: 0.06206 | Val Alpha DiceLoss: 0.08601 | Val Alpha Dice: 0.92191 | Val Alpha IoU: 0.85637 | Val RGB MAE(in): 0.15966 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_038.png
# No improvement. patience=1/15
#
# Epoch 39/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.92414 | Train RGB: 0.15471 | Train Alpha BCE: 0.05708 | Train Alpha DiceLoss: 0.09349 | Train Alpha Dice: 0.91948 | Train Alpha IoU: 0.85541 | Train RGB MAE(in): 0.15471
# Val loss: 0.93844 | Val RGB: 0.15871 | Val Alpha BCE: 0.05974 | Val Alpha DiceLoss: 0.08516 | Val Alpha Dice: 0.92337 | Val Alpha IoU: 0.85879 | Val RGB MAE(in): 0.15871 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_039.png
# No improvement. patience=2/15
#
# Epoch 40/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.92357 | Train RGB: 0.15460 | Train Alpha BCE: 0.05780 | Train Alpha DiceLoss: 0.09277 | Train Alpha Dice: 0.91984 | Train Alpha IoU: 0.85565 | Train RGB MAE(in): 0.15460
# Val loss: 0.92899 | Val RGB: 0.15820 | Val Alpha BCE: 0.05585 | Val Alpha DiceLoss: 0.08215 | Val Alpha Dice: 0.92676 | Val Alpha IoU: 0.86444 | Val RGB MAE(in): 0.15820 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_040.png
# Best model updated. best_val_loss=0.92899
#
# Epoch 41/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.91925 | Train RGB: 0.15443 | Train Alpha BCE: 0.05610 | Train Alpha DiceLoss: 0.09098 | Train Alpha Dice: 0.92143 | Train Alpha IoU: 0.85800 | Train RGB MAE(in): 0.15443
# Val loss: 0.92925 | Val RGB: 0.15697 | Val Alpha BCE: 0.05894 | Val Alpha DiceLoss: 0.08544 | Val Alpha Dice: 0.92298 | Val Alpha IoU: 0.85815 | Val RGB MAE(in): 0.15697 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_041.png
# No improvement. patience=1/15
#
# Epoch 42/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.91739 | Train RGB: 0.15374 | Train Alpha BCE: 0.05695 | Train Alpha DiceLoss: 0.09175 | Train Alpha Dice: 0.92101 | Train Alpha IoU: 0.85779 | Train RGB MAE(in): 0.15374
# Val loss: 0.96774 | Val RGB: 0.16182 | Val Alpha BCE: 0.06385 | Val Alpha DiceLoss: 0.09478 | Val Alpha Dice: 0.91557 | Val Alpha IoU: 0.84530 | Val RGB MAE(in): 0.16182 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_042.png
# No improvement. patience=2/15
#
# Epoch 43/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.90023 | Train RGB: 0.15181 | Train Alpha BCE: 0.05378 | Train Alpha DiceLoss: 0.08739 | Train Alpha Dice: 0.92476 | Train Alpha IoU: 0.86355 | Train RGB MAE(in): 0.15181
# Val loss: 0.95289 | Val RGB: 0.16102 | Val Alpha BCE: 0.06117 | Val Alpha DiceLoss: 0.08662 | Val Alpha Dice: 0.92245 | Val Alpha IoU: 0.85763 | Val RGB MAE(in): 0.16102 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_043.png
# No improvement. patience=3/15
#
# Epoch 44/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.90945 | Train RGB: 0.15240 | Train Alpha BCE: 0.05683 | Train Alpha DiceLoss: 0.09063 | Train Alpha Dice: 0.92188 | Train Alpha IoU: 0.85905 | Train RGB MAE(in): 0.15240
# Val loss: 0.91818 | Val RGB: 0.15552 | Val Alpha BCE: 0.05860 | Val Alpha DiceLoss: 0.08196 | Val Alpha Dice: 0.92587 | Val Alpha IoU: 0.86329 | Val RGB MAE(in): 0.15552 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_044.png
# Best model updated. best_val_loss=0.91818
#
# Epoch 45/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.89204 | Train RGB: 0.15073 | Train Alpha BCE: 0.05293 | Train Alpha DiceLoss: 0.08548 | Train Alpha Dice: 0.92645 | Train Alpha IoU: 0.86635 | Train RGB MAE(in): 0.15073
# Val loss: 0.91867 | Val RGB: 0.15598 | Val Alpha BCE: 0.05643 | Val Alpha DiceLoss: 0.08232 | Val Alpha Dice: 0.92628 | Val Alpha IoU: 0.86358 | Val RGB MAE(in): 0.15598 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_045.png
# No improvement. patience=1/15
#
# Epoch 46/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.89306 | Train RGB: 0.15057 | Train Alpha BCE: 0.05356 | Train Alpha DiceLoss: 0.08662 | Train Alpha Dice: 0.92529 | Train Alpha IoU: 0.86474 | Train RGB MAE(in): 0.15057
# Val loss: 0.90408 | Val RGB: 0.15372 | Val Alpha BCE: 0.05390 | Val Alpha DiceLoss: 0.08160 | Val Alpha Dice: 0.92794 | Val Alpha IoU: 0.86670 | Val RGB MAE(in): 0.15372 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_046.png
# Best model updated. best_val_loss=0.90408
#
# Epoch 47/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.89451 | Train RGB: 0.15081 | Train Alpha BCE: 0.05359 | Train Alpha DiceLoss: 0.08686 | Train Alpha Dice: 0.92486 | Train Alpha IoU: 0.86432 | Train RGB MAE(in): 0.15081
# Val loss: 0.90789 | Val RGB: 0.15472 | Val Alpha BCE: 0.05399 | Val Alpha DiceLoss: 0.08029 | Val Alpha Dice: 0.92880 | Val Alpha IoU: 0.86793 | Val RGB MAE(in): 0.15472 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_047.png
# No improvement. patience=1/15
#
# Epoch 48/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.89308 | Train RGB: 0.15053 | Train Alpha BCE: 0.05443 | Train Alpha DiceLoss: 0.08601 | Train Alpha Dice: 0.92557 | Train Alpha IoU: 0.86470 | Train RGB MAE(in): 0.15053
# Val loss: 0.91524 | Val RGB: 0.15622 | Val Alpha BCE: 0.05154 | Val Alpha DiceLoss: 0.08258 | Val Alpha Dice: 0.92837 | Val Alpha IoU: 0.86743 | Val RGB MAE(in): 0.15622 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_048.png
# No improvement. patience=2/15
#
# Epoch 49/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.88787 | Train RGB: 0.14946 | Train Alpha BCE: 0.05368 | Train Alpha DiceLoss: 0.08689 | Train Alpha Dice: 0.92527 | Train Alpha IoU: 0.86517 | Train RGB MAE(in): 0.14946
# Val loss: 0.90021 | Val RGB: 0.15385 | Val Alpha BCE: 0.05218 | Val Alpha DiceLoss: 0.07877 | Val Alpha Dice: 0.93037 | Val Alpha IoU: 0.87072 | Val RGB MAE(in): 0.15385 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_049.png
# Best model updated. best_val_loss=0.90021
#
# Epoch 50/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.86756 | Train RGB: 0.14693 | Train Alpha BCE: 0.05087 | Train Alpha DiceLoss: 0.08202 | Train Alpha Dice: 0.92942 | Train Alpha IoU: 0.87224 | Train RGB MAE(in): 0.14693
# Val loss: 0.93842 | Val RGB: 0.15854 | Val Alpha BCE: 0.06080 | Val Alpha DiceLoss: 0.08491 | Val Alpha Dice: 0.92386 | Val Alpha IoU: 0.85976 | Val RGB MAE(in): 0.15854 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_050.png
# No improvement. patience=1/15
#
# Epoch 51/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.87404 | Train RGB: 0.14767 | Train Alpha BCE: 0.05200 | Train Alpha DiceLoss: 0.08368 | Train Alpha Dice: 0.92758 | Train Alpha IoU: 0.86932 | Train RGB MAE(in): 0.14767
# Val loss: 0.94856 | Val RGB: 0.15895 | Val Alpha BCE: 0.06497 | Val Alpha DiceLoss: 0.08886 | Val Alpha Dice: 0.91872 | Val Alpha IoU: 0.85066 | Val RGB MAE(in): 0.15895 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_051.png
# No improvement. patience=2/15
#
# Epoch 52/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.87305 | Train RGB: 0.14724 | Train Alpha BCE: 0.05270 | Train Alpha DiceLoss: 0.08412 | Train Alpha Dice: 0.92735 | Train Alpha IoU: 0.86889 | Train RGB MAE(in): 0.14724
# Val loss: 0.89693 | Val RGB: 0.15270 | Val Alpha BCE: 0.05468 | Val Alpha DiceLoss: 0.07875 | Val Alpha Dice: 0.92928 | Val Alpha IoU: 0.86891 | Val RGB MAE(in): 0.15270 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_052.png
# Best model updated. best_val_loss=0.89693
#
# Epoch 53/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.85749 | Train RGB: 0.14563 | Train Alpha BCE: 0.04953 | Train Alpha DiceLoss: 0.07981 | Train Alpha Dice: 0.93116 | Train Alpha IoU: 0.87533 | Train RGB MAE(in): 0.14563
# Val loss: 0.88896 | Val RGB: 0.15155 | Val Alpha BCE: 0.05245 | Val Alpha DiceLoss: 0.07878 | Val Alpha Dice: 0.93028 | Val Alpha IoU: 0.87055 | Val RGB MAE(in): 0.15155 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_053.png
# Best model updated. best_val_loss=0.88896
#
# Epoch 54/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.85686 | Train RGB: 0.14544 | Train Alpha BCE: 0.05019 | Train Alpha DiceLoss: 0.07946 | Train Alpha Dice: 0.93119 | Train Alpha IoU: 0.87490 | Train RGB MAE(in): 0.14544
# Val loss: 0.91204 | Val RGB: 0.15453 | Val Alpha BCE: 0.05645 | Val Alpha DiceLoss: 0.08295 | Val Alpha Dice: 0.92614 | Val Alpha IoU: 0.86334 | Val RGB MAE(in): 0.15453 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_054.png
# No improvement. patience=1/15
#
# Epoch 55/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.84738 | Train RGB: 0.14368 | Train Alpha BCE: 0.04907 | Train Alpha DiceLoss: 0.07990 | Train Alpha Dice: 0.93117 | Train Alpha IoU: 0.87613 | Train RGB MAE(in): 0.14368
# Val loss: 0.90416 | Val RGB: 0.15407 | Val Alpha BCE: 0.05449 | Val Alpha DiceLoss: 0.07933 | Val Alpha Dice: 0.92867 | Val Alpha IoU: 0.86793 | Val RGB MAE(in): 0.15407 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_055.png
# No improvement. patience=2/15
#
# Epoch 56/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.85124 | Train RGB: 0.14406 | Train Alpha BCE: 0.05057 | Train Alpha DiceLoss: 0.08039 | Train Alpha Dice: 0.93055 | Train Alpha IoU: 0.87523 | Train RGB MAE(in): 0.14406
# Val loss: 0.89710 | Val RGB: 0.15313 | Val Alpha BCE: 0.05515 | Val Alpha DiceLoss: 0.07630 | Val Alpha Dice: 0.93062 | Val Alpha IoU: 0.87156 | Val RGB MAE(in): 0.15313 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_056.png
# No improvement. patience=3/15
#
# Epoch 57/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.84571 | Train RGB: 0.14349 | Train Alpha BCE: 0.04919 | Train Alpha DiceLoss: 0.07908 | Train Alpha Dice: 0.93176 | Train Alpha IoU: 0.87639 | Train RGB MAE(in): 0.14349
# Val loss: 0.89838 | Val RGB: 0.15404 | Val Alpha BCE: 0.05426 | Val Alpha DiceLoss: 0.07392 | Val Alpha Dice: 0.93261 | Val Alpha IoU: 0.87494 | Val RGB MAE(in): 0.15404 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_057.png
# No improvement. patience=4/15
#
# Epoch 58/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.82764 | Train RGB: 0.14182 | Train Alpha BCE: 0.04589 | Train Alpha DiceLoss: 0.07265 | Train Alpha Dice: 0.93747 | Train Alpha IoU: 0.88524 | Train RGB MAE(in): 0.14182
# Val loss: 0.91905 | Val RGB: 0.15746 | Val Alpha BCE: 0.05324 | Val Alpha DiceLoss: 0.07849 | Val Alpha Dice: 0.93042 | Val Alpha IoU: 0.87084 | Val RGB MAE(in): 0.15746 | LR: 0.000500
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_058.png
# No improvement. patience=5/15
#
# Epoch 59/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.83068 | Train RGB: 0.14190 | Train Alpha BCE: 0.04679 | Train Alpha DiceLoss: 0.07439 | Train Alpha Dice: 0.93578 | Train Alpha IoU: 0.88251 | Train RGB MAE(in): 0.14190
# Val loss: 0.90757 | Val RGB: 0.15486 | Val Alpha BCE: 0.05626 | Val Alpha DiceLoss: 0.07700 | Val Alpha Dice: 0.93027 | Val Alpha IoU: 0.87107 | Val RGB MAE(in): 0.15486 | LR: 0.000250
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_059.png
# No improvement. patience=6/15
#
# Epoch 60/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.80454 | Train RGB: 0.13807 | Train Alpha BCE: 0.04372 | Train Alpha DiceLoss: 0.07045 | Train Alpha Dice: 0.93972 | Train Alpha IoU: 0.89000 | Train RGB MAE(in): 0.13807
# Val loss: 0.88790 | Val RGB: 0.15217 | Val Alpha BCE: 0.05440 | Val Alpha DiceLoss: 0.07267 | Val Alpha Dice: 0.93392 | Val Alpha IoU: 0.87728 | Val RGB MAE(in): 0.15217 | LR: 0.000250
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_060.png
# Best model updated. best_val_loss=0.88790
#
# Epoch 61/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.79974 | Train RGB: 0.13752 | Train Alpha BCE: 0.04315 | Train Alpha DiceLoss: 0.06898 | Train Alpha Dice: 0.94065 | Train Alpha IoU: 0.89183 | Train RGB MAE(in): 0.13752
# Val loss: 0.86584 | Val RGB: 0.14854 | Val Alpha BCE: 0.05281 | Val Alpha DiceLoss: 0.07032 | Val Alpha Dice: 0.93598 | Val Alpha IoU: 0.88072 | Val RGB MAE(in): 0.14854 | LR: 0.000250
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_061.png
# Best model updated. best_val_loss=0.86584
#
# Epoch 62/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.79581 | Train RGB: 0.13664 | Train Alpha BCE: 0.04306 | Train Alpha DiceLoss: 0.06955 | Train Alpha Dice: 0.94001 | Train Alpha IoU: 0.89099 | Train RGB MAE(in): 0.13664
# Val loss: 0.89488 | Val RGB: 0.15286 | Val Alpha BCE: 0.05803 | Val Alpha DiceLoss: 0.07255 | Val Alpha Dice: 0.93308 | Val Alpha IoU: 0.87603 | Val RGB MAE(in): 0.15286 | LR: 0.000250
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_062.png
# No improvement. patience=1/15
#
# Epoch 63/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.79251 | Train RGB: 0.13650 | Train Alpha BCE: 0.04204 | Train Alpha DiceLoss: 0.06798 | Train Alpha Dice: 0.94166 | Train Alpha IoU: 0.89311 | Train RGB MAE(in): 0.13650
# Val loss: 0.87529 | Val RGB: 0.14975 | Val Alpha BCE: 0.05549 | Val Alpha DiceLoss: 0.07104 | Val Alpha Dice: 0.93446 | Val Alpha IoU: 0.87830 | Val RGB MAE(in): 0.14975 | LR: 0.000250
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_063.png
# No improvement. patience=2/15
#
# Epoch 64/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.79317 | Train RGB: 0.13611 | Train Alpha BCE: 0.04324 | Train Alpha DiceLoss: 0.06938 | Train Alpha Dice: 0.94025 | Train Alpha IoU: 0.89117 | Train RGB MAE(in): 0.13611
# Val loss: 0.88103 | Val RGB: 0.15060 | Val Alpha BCE: 0.05523 | Val Alpha DiceLoss: 0.07281 | Val Alpha Dice: 0.93318 | Val Alpha IoU: 0.87578 | Val RGB MAE(in): 0.15060 | LR: 0.000250
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_064.png
# No improvement. patience=3/15
#
# Epoch 65/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.78026 | Train RGB: 0.13439 | Train Alpha BCE: 0.04179 | Train Alpha DiceLoss: 0.06654 | Train Alpha Dice: 0.94275 | Train Alpha IoU: 0.89513 | Train RGB MAE(in): 0.13439
# Val loss: 0.88467 | Val RGB: 0.15103 | Val Alpha BCE: 0.05725 | Val Alpha DiceLoss: 0.07228 | Val Alpha Dice: 0.93336 | Val Alpha IoU: 0.87645 | Val RGB MAE(in): 0.15103 | LR: 0.000250
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_065.png
# No improvement. patience=4/15
#
# Epoch 66/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.77779 | Train RGB: 0.13412 | Train Alpha BCE: 0.04142 | Train Alpha DiceLoss: 0.06576 | Train Alpha Dice: 0.94336 | Train Alpha IoU: 0.89677 | Train RGB MAE(in): 0.13412
# Val loss: 0.87420 | Val RGB: 0.14955 | Val Alpha BCE: 0.05442 | Val Alpha DiceLoss: 0.07204 | Val Alpha Dice: 0.93429 | Val Alpha IoU: 0.87807 | Val RGB MAE(in): 0.14955 | LR: 0.000250
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_066.png
# No improvement. patience=5/15
#
# Epoch 67/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.77564 | Train RGB: 0.13404 | Train Alpha BCE: 0.04066 | Train Alpha DiceLoss: 0.06479 | Train Alpha Dice: 0.94421 | Train Alpha IoU: 0.89744 | Train RGB MAE(in): 0.13404
# Val loss: 0.90379 | Val RGB: 0.15536 | Val Alpha BCE: 0.05605 | Val Alpha DiceLoss: 0.07096 | Val Alpha Dice: 0.93437 | Val Alpha IoU: 0.87811 | Val RGB MAE(in): 0.15536 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_067.png
# No improvement. patience=6/15
#
# Epoch 68/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.75488 | Train RGB: 0.13067 | Train Alpha BCE: 0.03890 | Train Alpha DiceLoss: 0.06265 | Train Alpha Dice: 0.94633 | Train Alpha IoU: 0.90214 | Train RGB MAE(in): 0.13067
# Val loss: 0.86131 | Val RGB: 0.14781 | Val Alpha BCE: 0.05287 | Val Alpha DiceLoss: 0.06941 | Val Alpha Dice: 0.93647 | Val Alpha IoU: 0.88162 | Val RGB MAE(in): 0.14781 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_068.png
# Best model updated. best_val_loss=0.86131
#
# Epoch 69/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.75221 | Train RGB: 0.13050 | Train Alpha BCE: 0.03831 | Train Alpha DiceLoss: 0.06139 | Train Alpha Dice: 0.94748 | Train Alpha IoU: 0.90351 | Train RGB MAE(in): 0.13050
# Val loss: 0.86452 | Val RGB: 0.14842 | Val Alpha BCE: 0.05394 | Val Alpha DiceLoss: 0.06846 | Val Alpha Dice: 0.93703 | Val Alpha IoU: 0.88279 | Val RGB MAE(in): 0.14842 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_069.png
# No improvement. patience=1/15
#
# Epoch 70/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.75593 | Train RGB: 0.13054 | Train Alpha BCE: 0.03975 | Train Alpha DiceLoss: 0.06348 | Train Alpha Dice: 0.94516 | Train Alpha IoU: 0.90018 | Train RGB MAE(in): 0.13054
# Val loss: 0.86993 | Val RGB: 0.14934 | Val Alpha BCE: 0.05461 | Val Alpha DiceLoss: 0.06863 | Val Alpha Dice: 0.93659 | Val Alpha IoU: 0.88205 | Val RGB MAE(in): 0.14934 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_070.png
# No improvement. patience=2/15
#
# Epoch 71/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.75572 | Train RGB: 0.13037 | Train Alpha BCE: 0.04007 | Train Alpha DiceLoss: 0.06378 | Train Alpha Dice: 0.94497 | Train Alpha IoU: 0.89988 | Train RGB MAE(in): 0.13037
# Val loss: 0.85594 | Val RGB: 0.14704 | Val Alpha BCE: 0.05270 | Val Alpha DiceLoss: 0.06801 | Val Alpha Dice: 0.93752 | Val Alpha IoU: 0.88361 | Val RGB MAE(in): 0.14704 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_071.png
# Best model updated. best_val_loss=0.85594
#
# Epoch 72/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.77639 | Train RGB: 0.13289 | Train Alpha BCE: 0.04307 | Train Alpha DiceLoss: 0.06884 | Train Alpha Dice: 0.94056 | Train Alpha IoU: 0.89277 | Train RGB MAE(in): 0.13289
# Val loss: 0.86454 | Val RGB: 0.14883 | Val Alpha BCE: 0.05283 | Val Alpha DiceLoss: 0.06755 | Val Alpha Dice: 0.93780 | Val Alpha IoU: 0.88415 | Val RGB MAE(in): 0.14883 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_072.png
# No improvement. patience=1/15
#
# Epoch 73/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.75419 | Train RGB: 0.13026 | Train Alpha BCE: 0.03940 | Train Alpha DiceLoss: 0.06346 | Train Alpha Dice: 0.94533 | Train Alpha IoU: 0.90029 | Train RGB MAE(in): 0.13026
# Val loss: 0.86852 | Val RGB: 0.14858 | Val Alpha BCE: 0.05645 | Val Alpha DiceLoss: 0.06919 | Val Alpha Dice: 0.93576 | Val Alpha IoU: 0.88071 | Val RGB MAE(in): 0.14858 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_073.png
# No improvement. patience=2/15
#
# Epoch 74/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.73966 | Train RGB: 0.12861 | Train Alpha BCE: 0.03703 | Train Alpha DiceLoss: 0.05958 | Train Alpha Dice: 0.94916 | Train Alpha IoU: 0.90677 | Train RGB MAE(in): 0.12861
# Val loss: 0.86070 | Val RGB: 0.14737 | Val Alpha BCE: 0.05514 | Val Alpha DiceLoss: 0.06871 | Val Alpha Dice: 0.93674 | Val Alpha IoU: 0.88233 | Val RGB MAE(in): 0.14737 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_074.png
# No improvement. patience=3/15
#
# Epoch 75/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.74634 | Train RGB: 0.12901 | Train Alpha BCE: 0.03888 | Train Alpha DiceLoss: 0.06238 | Train Alpha Dice: 0.94633 | Train Alpha IoU: 0.90236 | Train RGB MAE(in): 0.12901
# Val loss: 0.85751 | Val RGB: 0.14703 | Val Alpha BCE: 0.05510 | Val Alpha DiceLoss: 0.06726 | Val Alpha Dice: 0.93759 | Val Alpha IoU: 0.88377 | Val RGB MAE(in): 0.14703 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_075.png
# No improvement. patience=4/15
#
# Epoch 76/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.73726 | Train RGB: 0.12821 | Train Alpha BCE: 0.03697 | Train Alpha DiceLoss: 0.05926 | Train Alpha Dice: 0.94913 | Train Alpha IoU: 0.90661 | Train RGB MAE(in): 0.12821
# Val loss: 0.87538 | Val RGB: 0.15033 | Val Alpha BCE: 0.05499 | Val Alpha DiceLoss: 0.06874 | Val Alpha Dice: 0.93664 | Val Alpha IoU: 0.88211 | Val RGB MAE(in): 0.15033 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_076.png
# No improvement. patience=5/15
#
# Epoch 77/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.74499 | Train RGB: 0.12928 | Train Alpha BCE: 0.03835 | Train Alpha DiceLoss: 0.06024 | Train Alpha Dice: 0.94816 | Train Alpha IoU: 0.90454 | Train RGB MAE(in): 0.12928
# Val loss: 0.85579 | Val RGB: 0.14695 | Val Alpha BCE: 0.05411 | Val Alpha DiceLoss: 0.06692 | Val Alpha Dice: 0.93817 | Val Alpha IoU: 0.88478 | Val RGB MAE(in): 0.14695 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_077.png
# Best model updated. best_val_loss=0.85579
#
# Epoch 78/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.73630 | Train RGB: 0.12802 | Train Alpha BCE: 0.03712 | Train Alpha DiceLoss: 0.05909 | Train Alpha Dice: 0.94936 | Train Alpha IoU: 0.90705 | Train RGB MAE(in): 0.12802
# Val loss: 0.85421 | Val RGB: 0.14692 | Val Alpha BCE: 0.05301 | Val Alpha DiceLoss: 0.06658 | Val Alpha Dice: 0.93884 | Val Alpha IoU: 0.88598 | Val RGB MAE(in): 0.14692 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_078.png
# Best model updated. best_val_loss=0.85421
#
# Epoch 79/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.74520 | Train RGB: 0.12874 | Train Alpha BCE: 0.03879 | Train Alpha DiceLoss: 0.06272 | Train Alpha Dice: 0.94620 | Train Alpha IoU: 0.90201 | Train RGB MAE(in): 0.12874
# Val loss: 0.86047 | Val RGB: 0.14792 | Val Alpha BCE: 0.05379 | Val Alpha DiceLoss: 0.06709 | Val Alpha Dice: 0.93795 | Val Alpha IoU: 0.88440 | Val RGB MAE(in): 0.14792 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_079.png
# No improvement. patience=1/15
#
# Epoch 80/80
# Train:   0%|          | 0/96 [00:00<?, ?it/s]
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Train loss: 0.74731 | Train RGB: 0.12857 | Train Alpha BCE: 0.04026 | Train Alpha DiceLoss: 0.06421 | Train Alpha Dice: 0.94475 | Train Alpha IoU: 0.90011 | Train RGB MAE(in): 0.12857
# Val loss: 0.86101 | Val RGB: 0.14796 | Val Alpha BCE: 0.05345 | Val Alpha DiceLoss: 0.06774 | Val Alpha Dice: 0.93781 | Val Alpha IoU: 0.88409 | Val RGB MAE(in): 0.14796 | LR: 0.000125
# Saved sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_080.png
# No improvement. patience=2/15
#
# Training finished. Best epoch: 78, Best val loss: 0.85421
# Eval:   0%|          | 0/12 [00:00<?, ?it/s]
# Test metrics:
# loss: 0.857049
# rgb_inside_loss: 0.147906
# alpha_bce: 0.051411
# alpha_dice: 0.066110
# bg_rgb_loss: 0.000000
# alpha_dice_metric: 0.939428
# alpha_iou_metric: 0.886932
# rgb_mae_inside_metric: 0.147906
# Saved test sample: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/samples/epoch_999.png
# Best model path: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/checkpoints/best_model.pt
# Log path: /content/drive/MyDrive/borderModel2/grape_ver1/experiments/exp_color_rgba_128to400_grape_new_v001/logs/train_log.csv

# %%
print(1)
